# %%
import os
os.getcwd()
# Out:
# '/Users/seantyh/lago/comet/etc'

# %%
from pathlib import Path
import pickle

data = pickle.loads(Path('../data/tencent-compound-c2.pkl').read_bytes())

# %%
list(data["test"].keys())
# Out:
# ['comps', 'consts', 'comps_text', 'c1_text', 'c2_text']

# %%
data ["val"]["comps"].dtype
# Out:
# dtype('float32')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import datasets
hf_data = datasets.load_dataset("../data/tencent-c4")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset tencent-c4 downloaded and prepared to /Users/seantyh/.cache/huggingface/datasets/tencent-c4/default/0.0.0/e8b1a0e266ff5b157db1e49e516ed260e793752a2114335a252eddd1115c1512. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
hf_data["test"][:3]
# Out:
# {'compound': [[-0.10237299650907516,
#    -0.31069299578666687,
#    0.4990380108356476,
#    -0.2711640000343323,
#    0.18894800543785095,
#    -0.046484000980854034,
#    0.3806169927120209,
#    0.6116930246353149,
#    -0.016795000061392784,
#    -0.11244899779558182,
#    -0.15426500141620636,
#    0.35633501410484314,
#    0.032381001859903336,
#    -0.5848519802093506,
#    -0.07501599937677383,
#    -0.2916179895401001,
#    0.020055999979376793,
#    0.3411319851875305,
#    -0.4148080050945282,
#    0.23280400037765503,
#    0.3708760142326355,
#    0.4696289896965027,
#    -0.04323599860072136,
#    -0.08780299872159958,
#    -0.21556800603866577,
#    0.09037300199270248,
#    0.3508929908275604,
#    -0.15773500502109528,
#    0.23877599835395813,
#    0.14028599858283997,
#    0.10020700097084045,
#    -0.5593270063400269,
#    -0.6010450124740601,
#    0.14688099920749664,
#    0.10456500202417374,
#    0.25076401233673096,
#    0.22999300062656403,
# ...
